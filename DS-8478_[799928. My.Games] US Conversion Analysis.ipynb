# %% [markdown]
# # Install

# %%
import pandas as pd
import pandas_gbq
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter,FuncFormatter
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
from IPython import get_ipython
import warnings
import matplotlib.dates as mdates
from matplotlib.patches import Patch
import os
import textwrap
# import abpack.gbq as gbq
import pyarrow.parquet as pq

# %% [markdown]
# # Query

# %%
sheet_url = '/Users/p.liamin/Documents/Xsolla Researches/DS-8478_[799928. My.Games] US Conversion Analysis/df_main_my_games.parquet'
df_main_my_games = pd.read_parquet(sheet_url)
display(df_main_my_games)
# Out:
#        internal_date        user_id  \
# 0         2025-12-18   36693_282250
# 1         2025-12-18  539699_282250
# 2         2025-12-18  539080_282250
# 3         2025-12-18  539953_282250
# 4         2025-12-18  456628_282250
# ...              ...            ...
# 681330    2025-09-14  106625_282250
# 681331    2025-09-14  109534_282250
# 681332    2025-09-14  109534_282250
# 681333    2025-09-14  109374_282250
# 681334    2025-09-14  109374_282250
#
#                                         user_access_token user_browser_type  \
# 0       5uu8HClNieg7SxNdMx85Soc6DAtWKJnE_lc_en_bg_1414...            chrome
# 1       5uu8guMyRftrT7wAUQcIsZzPwvRSNf3T_lc_en_bg_1414...            chrome
# 2       5uu8SAslONEdMMMwBJ1xsnrP9OUmXtqs_lc_en_bg_1414...            safari
# 3       5uu8MJzqYBoFUyTiMuw62tUl3BbG22c1_lc_en_bg_1414...            safari
# 4       5uu8oqPo4xlmzGNETEVuvY2QQIja8Kbk_lc_en_bg_1414...            chrome
# ...                                                   ...               ...
# 681330  5uu8lLqptiB1xrfTHfbewxCzEdRG7Pn3_lc_en_bg_1414...            safari
# 681331  5uu8VLZEuTRAn0x3bU2cWHV6oysRjv3i_lc_en_bg_1414...            safari
# 681332  5uu8VLZEuTRAn0x3bU2cWHV6oysRjv3i_lc_en_bg_1414...            safari
# 681333  5uu8gJLMqnocDXDSDfnbaCgsV9cebAil_lc_en_bg_1414...            safari
# 681334  5uu8gJLMqnocDXDSDfnbaCgsV9cebAil_lc_en_bg_1414...            safari
#
#         is_iframe user_operation_system theme_version device_category  \
# 0               1               Android        mobile          Mobile
# 1               1               Android        mobile          Mobile
# 2               1                   iOS        mobile          Mobile
# 3               1                   iOS        mobile          Mobile
# 4               1               Android        mobile          Mobile
# ...           ...                   ...           ...             ...
# 681330          1                   iOS        mobile          Mobile
# 681331          1                   iOS        mobile          Mobile
# 681332          1                   iOS        mobile          Mobile
# 681333          1                   iOS        mobile          Mobile
# 681334          1                   iOS        mobile          Mobile
#
#         is_saved_open saved_account_info  ...  \
# 0                   1           card_pay  ...
# 1                   0            without  ...
# 2                   0            without  ...
# 3                   0            without  ...
# 4                   1            without  ...
# ...               ...                ...  ...
# 681330              1           card_pay  ...
# 681331              1            without  ...
# 681332              1            Unknown  ...
# 681333              1            without  ...
# 681334              1            Unknown  ...
#
#                                                 game_name  \
# 0                               [XSOLLA][TP] Tacticool WW
# 1                             [XSOLLA][TP] Rush Royale WW
# 2                             [XSOLLA][TP] Rush Royale WW
# 3                             [XSOLLA][WV] Rush Royale WW
# 4                                     [XSOLLA][WV] LTS WW
# ...                                                   ...
# 681330  [XSOLLA MENA][PROD] Grand Hotel Mania USD (US ...
# 681331  [XSOLLA MENA][PROD] Grand Hotel Mania USD (US ...
# 681332  [XSOLLA MENA][PROD] Grand Hotel Mania USD (US ...
# 681333  [XSOLLA MENA][PROD] Grand Hotel Mania USD (US ...
# 681334  [XSOLLA MENA][PROD] Grand Hotel Mania USD (US ...
#
#        token_show_shopping_cart token_interact create_invoice_old instance_id  \
# 0                             1              1                  1        1380
# 1                             1              1                  1        3431
# 2                             1              1                  1        3175
# 3                             1              1                  1        3175
# 4                             1              1                  1        3679
# ...                         ...            ...                ...         ...
# 681330                        1              1                  1        1380
# 681331                        1              1                  1        3679
# 681332                        1              1                  0        1380
# 681333                        1              1                  1        3175
# 681334                        1              1                  0          24
#
#        bi_instance validation_error afs_canceled ps_canceled done_just
# 0           1380.0                0            0           0         1
# 1           3431.0                0            0           0         1
# 2           3175.0                0            0           0         1
# 3           3175.0                0            0           0         1
# 4           3679.0                0            0           0         1
# ...            ...              ...          ...         ...       ...
# 681330      1380.0                0            0           0         1
# 681331      3679.0                0            0           0         1
# 681332         NaN                0            0           0         0
# 681333      3175.0                0            0           0         1
# 681334         NaN                0            0           0         0
#
# [681335 rows x 28 columns]

# %% [markdown]
# # Graphs

# %% [markdown]
# ## YoY Metrics Comparison (Xsolla Corporate Style)
#
# Comparison by calendar year, regardless of month coverage.

# %%
# YoY metrics by calendar year (comparison-only mode)

df_main_my_games_yoy = df_main_my_games.copy()
df_main_my_games_yoy['internal_date'] = pd.to_datetime(df_main_my_games_yoy['internal_date'], errors='coerce')
df_main_my_games_yoy = df_main_my_games_yoy.dropna(subset=['internal_date'])
df_main_my_games_yoy['year'] = df_main_my_games_yoy['internal_date'].dt.year


def _distinct_count(series):
    return series.dropna().nunique()


def _calc_yoy_metrics(group):
    open_cnt = _distinct_count(group['user_access_token'])

    show_sc_cnt = _distinct_count(
        group.loc[group['token_show_shopping_cart'].astype(str) == '1', 'user_access_token']
    )
    interact_cnt = _distinct_count(
        group.loc[group['token_interact'].astype(str) == '1', 'user_access_token']
    )
    create_cnt = _distinct_count(
        group.loc[
            (group['create_invoice_old'] == 1) & (group['instance_id'] == group['bi_instance']),
            'user_access_token'
        ]
    )
    cancel_cnt = _distinct_count(
        group.loc[
            (group['validation_error'] == 1)
            | (group['afs_canceled'] == 1)
            | (group['ps_canceled'] == 1),
            'user_access_token'
        ]
    )
    done_cnt = _distinct_count(
        group.loc[
            (group['instance_id'] == group['bi_instance']) & (group['done_just'] == 1),
            'user_access_token'
        ]
    )

    return pd.Series(
        {
            'Open': open_cnt,
            'CR_OPEN_SHOW_SC': (show_sc_cnt / open_cnt * 100) if open_cnt else np.nan,
            'CR_OPEN_INTERACT': (interact_cnt / open_cnt * 100) if open_cnt else np.nan,
            'CR_OPEN_CREATE': (create_cnt / open_cnt * 100) if open_cnt else np.nan,
            'AFS_PS_Validation_cancel': (cancel_cnt / open_cnt * 100) if open_cnt else np.nan,
            'CR_CREATE_DONE': (done_cnt / create_cnt * 100) if create_cnt else np.nan,
            'CR_OPEN_DONE': (done_cnt / open_cnt * 100) if open_cnt else np.nan,
        }
    )


yoy_metrics_df = (
    df_main_my_games_yoy
    .groupby('year', as_index=False)
    .apply(_calc_yoy_metrics, include_groups=False)
    .reset_index(drop=True)
    .sort_values('year')
)

import sys
from pathlib import Path

_xsolla_root = Path.cwd().parent
if str(_xsolla_root) not in sys.path:
    sys.path.insert(0, str(_xsolla_root))

from html import escape
from IPython.display import HTML, display
from utils.style import XS
from utils.html_style import XS_OUTER_WRAP_START, XS_OUTER_WRAP_END

METRICS_YOY_ORDER = ['CR_OPEN_INTERACT', 'CR_OPEN_CREATE', 'CR_CREATE_DONE', 'CR_OPEN_DONE']
METRICS_YOY_LABELS = {
    'CR_OPEN_INTERACT': 'CR Open-Interact',
    'CR_OPEN_CREATE': 'CR Open-Create',
    'CR_CREATE_DONE': 'CR Create-Done',
    'CR_OPEN_DONE': 'CR Open-Done',
}
year_list_sorted = sorted(yoy_metrics_df['year'].dropna().unique().tolist())

yoy_plot_df = yoy_metrics_df[['year'] + METRICS_YOY_ORDER].copy()

# KPI cards (top row) — Top-3 Locale Metrics style
open_by_year = yoy_metrics_df[['year', 'Open']].copy()
open_kpi_html = ''.join(
    [
        (
            "<div class='kpi-card'>"
            f"<div class='kpi-head'>{int(r['year'])}</div>"
            f"<div class='kpi-value'>{int(r['Open']):,}</div>"
            "<div class='kpi-note'>Unique access tokens</div>"
            "</div>"
        )
        for _, r in open_by_year.iterrows()
    ]
)

# SVG grouped horizontal bars
svg_width = 980
left_pad = 190
right_pad = 90
top_pad = 44
row_gap = 72
bar_h = 18
group_gap = 8
inner_w = svg_width - left_pad - right_pad

max_val = float(np.nanmax(yoy_plot_df[METRICS_YOY_ORDER].to_numpy())) if len(yoy_plot_df) else 1.0
if max_val <= 0:
    max_val = 1.0

year_colors = [getattr(XS, 'S5', XS.PALETTE[0]), getattr(XS, 'S7', XS.PALETTE[1])]

def _xscale(v):
    return (float(v) / max_val) * inner_w if pd.notna(v) else 0.0

rows_svg = []
for row_idx, metric in enumerate(METRICS_YOY_ORDER):
    y_base = top_pad + row_idx * row_gap
    metric_label = METRICS_YOY_LABELS.get(metric, metric)
    rows_svg.append(
        f"<text x='{left_pad - 16}' y='{y_base + bar_h}' text-anchor='end' class='metric-label'>{escape(metric_label)}</text>"
    )
    rows_svg.append(
        f"<line x1='{left_pad}' y1='{y_base + bar_h + 16}' x2='{left_pad + inner_w}' y2='{y_base + bar_h + 16}' class='grid-line' />"
    )

    for y_idx, year in enumerate(year_list_sorted):
        val = float(yoy_plot_df.loc[yoy_plot_df['year'] == year, metric].iloc[0])
        y = y_base + y_idx * (bar_h + group_gap)
        w = _xscale(val)
        color = year_colors[y_idx % len(year_colors)]

        rows_svg.append(
            f"<rect x='{left_pad}' y='{y}' width='{w:.2f}' height='{bar_h}' rx='8' ry='8' fill='{color}' />"
        )
        rows_svg.append(
            f"<text x='{left_pad + w + 8:.2f}' y='{y + bar_h - 4}' class='val-label'>{val:.2f}%</text>"
        )

# X-axis ticks
axis_ticks = []
for t in np.linspace(0, max_val, 6):
    x = left_pad + _xscale(t)
    axis_ticks.append(f"<line x1='{x:.2f}' y1='20' x2='{x:.2f}' y2='{top_pad + len(METRICS_YOY_ORDER)*row_gap - 12}' class='tick-line' />")
    axis_ticks.append(f"<text x='{x:.2f}' y='{top_pad + len(METRICS_YOY_ORDER)*row_gap}' text-anchor='middle' class='tick-label'>{t:.1f}%</text>")

svg_height = top_pad + len(METRICS_YOY_ORDER) * row_gap + 26
legend_html = ''.join(
    [
        f"<div class='legend-item'><span class='sw' style='background:{year_colors[idx % len(year_colors)]};'></span>{int(year)}</div>"
        for idx, year in enumerate(year_list_sorted)
    ]
)

font_body = getattr(XS, 'FONT_BODY', getattr(XS, 'FONT_SANS', "'Roboto', sans-serif"))
font_title = getattr(XS, 'FONT_TITLE', font_body)
font_subtitle = getattr(XS, 'FONT_SUBTITLE', font_body)
color_s10 = getattr(XS, 'S10', '#B2F2FF')
color_s12 = getattr(XS, 'S12', '#EBFCFF')
color_s4 = getattr(XS, 'S4', '#135D6C')
color_s3 = getattr(XS, 'S3', '#0B3841')
color_s7 = getattr(XS, 'S7', '#31CAE8')
grid_major = getattr(XS, 'GRID_MAJOR', '#C0C0C0')
grid_minor = getattr(XS, 'GRID_MINOR', '#E6E6E6')

yoy_html = f"""
<!DOCTYPE html>
<html>
<head>
<meta charset='utf-8'>
<link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
<style>
  body {{ background:#FFFFFF; margin:0; padding:20px; font-family:{font_body}; color:{XS.TEXT_PRIMARY}; }}
  .chart-wrap {{ background:#FFFFFF; border:none; border-radius:14px; padding:6px 6px 12px; }}
  .title {{ font-size:36px; font-weight:700; margin-bottom:4px; font-family:{font_title}; color:{XS.TEXT_PRIMARY}; line-height:1.1; }}
  .subtitle {{ font-size:14px; color:{XS.TEXT_SECONDARY}; margin-bottom:12px; font-family:{font_subtitle}; }}
  .kpi-row {{ display:grid; grid-template-columns:repeat(2,minmax(0,1fr)); gap:12px; margin-bottom:14px; }}
  .kpi-card {{ border:2px solid #D3D3D3; border-radius:14px; background:#FFFFFF; overflow:hidden; }}
  .kpi-head {{ background:{color_s10}; color:{XS.TEXT_PRIMARY}; font-size:16px; font-weight:700; text-align:center; padding:6px 8px; font-family:{font_title}; }}
  .kpi-value {{ font-size:48px; font-weight:700; color:{color_s7}; margin:8px 0 0; text-align:center; font-family:{font_body}; line-height:1; }}
  .kpi-note {{ font-size:14px; color:{XS.TEXT_SECONDARY}; text-align:center; padding:6px 0 10px; font-family:{font_body}; }}
  .panel {{ background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:14px 14px 10px; }}
  .legend {{ display:flex; gap:22px; margin:0 0 10px; }}
  .legend-item {{ font-size:14px; color:{XS.TEXT_SECONDARY}; display:flex; align-items:center; gap:8px; font-family:{font_body}; }}
  .sw {{ width:20px; height:10px; border-radius:5px; display:inline-block; }}
  .metric-label {{ font-size:16px; fill:{XS.TEXT_PRIMARY}; font-weight:700; font-family:{font_body}; }}
  .val-label {{ font-size:12px; fill:{XS.TEXT_PRIMARY}; font-weight:700; font-family:{font_body}; }}
  .grid-line {{ stroke:{grid_major}; stroke-width:1; }}
  .tick-line {{ stroke:{grid_minor}; stroke-width:1; }}
  .tick-label {{ font-size:12px; fill:{XS.TEXT_SECONDARY}; font-family:{font_body}; }}
</style>
</head>
<body>
{XS_OUTER_WRAP_START}
<div class='chart-wrap'>
  <div class='title'>YoY Comparison</div>
  <div class='subtitle'>CR Open-Interact · CR Open-Create · CR Create-Done · CR Open-Done</div>
  <div class='kpi-row'>{open_kpi_html}</div>
  <div class='panel'>
    <div class='legend'>{legend_html}</div>
    <svg width='100%' viewBox='0 0 {svg_width} {svg_height}' preserveAspectRatio='xMinYMin meet' role='img' aria-label='YoY comparison chart'>
      {''.join(axis_ticks)}
      {''.join(rows_svg)}
    </svg>
  </div>
</div>
{XS_OUTER_WRAP_END}
</body>
</html>
"""

display(HTML(yoy_html))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset='utf-8'>
# <link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
# <style>
#   body { background:#FFFFFF; margin:0; padding:20px; font-family:'Roboto', sans-serif; color:#011627; }
#   .chart-wrap { background:#FFFFFF; border:none; border-radius:14px; padding:6px 6px 12px; }
#   .title { font-size:36px; font-weight:700; margin-bottom:4px; font-family:'Open Sans', sans-serif; color:#011627; line-height:1.1; }
#   .subtitle { font-size:14px; color:#595959; margin-bottom:12px; font-family:'Open Sans', sans-serif; }
#   .kpi-row { display:grid; grid-template-columns:repeat(2,minmax(0,1fr)); gap:12px; margin-bottom:14px; }
#   .kpi-card { border:2px solid #D3D3D3; border-radius:14px; background:#FFFFFF; overflow:hidden; }
#   .kpi-head { background:#B2F2FF; color:#011627; font-size:16px; font-weight:700; text-align:center; padding:6px 8px; font-family:'Open Sans', sans-serif; }
#   .kpi-value { font-size:48px; font-weight:700; color:#31CAE8; margin:8px 0 0; text-align:center; font-family:'Roboto', sans-serif; line-height:1; }
#   .kpi-note { font-size:14px; color:#595959; text-align:center; padding:6px 0 10px; font-family:'Roboto', sans-serif; }
#   .panel { background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:14px 14px 10px; }
#   .legend { display:flex; gap:22px; margin:0 0 10px; }
#   .legend-item { font-size:14px; color:#595959; display:flex; align-items:center; gap:8px; font-family:'Roboto', sans-serif; }
#   .sw { width:20px; height:10px; border-radius:5px; display:inline-block; }
#   .metric-label { font-size:16px; fill:#011627; font-weight:700; font-family:'Roboto', sans-serif; }
#   .val-label { font-size:12px; fill:#011627; font-weight:700; font-family:'Roboto', sans-serif; }
#   .grid-line { stroke:#C0C0C0; stroke-width:1; }
#   .tick-line { stroke:#E6E6E6; stroke-width:1; }
#   .tick-label { font-size:12px; fill:#595959; font-family:'Roboto', sans-serif; }
# </style>
# </head>
# <body>
#
# <div style="border-radius:12px; padding:24px 32px;
#             box-shadow:0 4px 20px rgba(0,0,0,0.08); border:1px solid #e2e8f0;">
#
# <div class='chart-wrap'>
#   <div class='title'>YoY Comparison</div>
#   <div class='subtitle'>CR Open-Interact · CR Open-Create · CR Create-Done · CR Open-Done</div>
#   <div class='kpi-row'><div class='kpi-card'><div class='kpi-head'>2025</div><div class='kpi-value'>100,262</div><div class='kpi-note'>Unique access tokens</div></div><div class='kpi-card'><div class='kpi-head'>2026</div><div class='kpi-value'>373,731</div><div class='kpi-note'>Unique access tokens</div></div></div>
#   <div class='panel'>
#     <div class='legend'><div class='legend-item'><span class='sw' style='background:#1B8398;'></span>2025</div><div class='legend-item'><span class='sw' style='background:#31CAE8;'></span>2026</div></div>
#     <svg width='100%' viewBox='0 0 980 358' preserveAspectRatio='xMinYMin meet' role='img' aria-label='YoY comparison chart'>
#       <line x1='190.00' y1='20' x2='190.00' y2='320' class='tick-line' /><text x='190.00' y='332' text-anchor='middle' class='tick-label'>0.0%</text><line x1='330.00' y1='20' x2='330.00' y2='320' class='tick-line' /><text x='330.00' y='332' text-anchor='middle' class='tick-label'>18.0%</text><line x1='470.00' y1='20' x2='470.00' y2='320' class='tick-line' /><text x='470.00' y='332' text-anchor='middle' class='tick-label'>35.9%</text><line x1='610.00' y1='20' x2='610.00' y2='320' class='tick-line' /><text x='610.00' y='332' text-anchor='middle' class='tick-label'>53.9%</text><line x1='750.00' y1='20' x2='750.00' y2='320' class='tick-line' /><text x='750.00' y='332' text-anchor='middle' class='tick-label'>71.9%</text><line x1='890.00' y1='20' x2='890.00' y2='320' class='tick-line' /><text x='890.00' y='332' text-anchor='middle' class='tick-label'>89.8%</text>
#       <text x='174' y='62' text-anchor='end' class='metric-label'>CR Open-Interact</text><line x1='190' y1='78' x2='890' y2='78' class='grid-line' /><rect x='190' y='44' width='601.68' height='18' rx='8' ry='8' fill='#1B8398' /><text x='799.68' y='58' class='val-label'>77.22%</text><rect x='190' y='70' width='533.73' height='18' rx='8' ry='8' fill='#31CAE8' /><text x='731.73' y='84' class='val-label'>68.50%</text><text x='174' y='134' text-anchor='end' class='metric-label'>CR Open-Create</text><line x1='190' y1='150' x2='890' y2='150' class='grid-line' /><rect x='190' y='116' width='501.09' height='18' rx='8' ry='8' fill='#1B8398' /><text x='699.09' y='130' class='val-label'>64.31%</text><rect x='190' y='142' width='461.46' height='18' rx='8' ry='8' fill='#31CAE8' /><text x='659.46' y='156' class='val-label'>59.22%</text><text x='174' y='206' text-anchor='end' class='metric-label'>CR Create-Done</text><line x1='190' y1='222' x2='890' y2='222' class='grid-line' /><rect x='190' y='188' width='683.33' height='18' rx='8' ry='8' fill='#1B8398' /><text x='881.33' y='202' class='val-label'>87.70%</text><rect x='190' y='214' width='700.00' height='18' rx='8' ry='8' fill='#31CAE8' /><text x='898.00' y='228' class='val-label'>89.84%</text><text x='174' y='278' text-anchor='end' class='metric-label'>CR Open-Done</text><line x1='190' y1='294' x2='890' y2='294' class='grid-line' /><rect x='190' y='260' width='439.45' height='18' rx='8' ry='8' fill='#1B8398' /><text x='637.45' y='274' class='val-label'>56.40%</text><rect x='190' y='286' width='414.57' height='18' rx='8' ry='8' fill='#31CAE8' /><text x='612.57' y='300' class='val-label'>53.21%</text>
#     </svg>
#   </div>
# </div>
# </div>
# </body>
# </html>

# %%
# YoY comparison by payment method (4 panels in one row)

import sys
from pathlib import Path
from html import escape
from IPython.display import HTML, display

_xsolla_root = Path.cwd().parent
if str(_xsolla_root) not in sys.path:
    sys.path.insert(0, str(_xsolla_root))

from utils.style import XS

# Human-readable metric names
METRICS_YOY_ORDER = ['CR_OPEN_INTERACT', 'CR_OPEN_CREATE', 'CR_CREATE_DONE', 'CR_OPEN_DONE']
METRICS_YOY_LABELS = {
    'CR_OPEN_INTERACT': 'CR Open-Interact',
    'CR_OPEN_CREATE': 'CR Open-Create',
    'CR_CREATE_DONE': 'CR Create-Done',
    'CR_OPEN_DONE': 'CR Open-Done',
}

# Required methods
PAYMENT_METHODS = [
    ('1380.Bank card', 'Bank card'),
    ('3175.Apple Pay', 'Apple Pay'),
    ('24.PayPal', 'PayPal'),
    ('3431.Google Pay', 'Google Pay'),
]

# Base dataframe
df_main_my_games_yoy_all = df_main_my_games.copy()
df_main_my_games_yoy_all['internal_date'] = pd.to_datetime(df_main_my_games_yoy_all['internal_date'], errors='coerce')
df_main_my_games_yoy_all = df_main_my_games_yoy_all.dropna(subset=['internal_date'])
df_main_my_games_yoy_all['year'] = df_main_my_games_yoy_all['internal_date'].dt.year


def _distinct_count(series):
    return series.dropna().nunique()


def _calc_yoy_metrics(group):
    open_cnt = _distinct_count(group['user_access_token'])
    interact_cnt = _distinct_count(
        group.loc[group['token_interact'].astype(str) == '1', 'user_access_token']
    )
    create_cnt = _distinct_count(
        group.loc[
            (group['create_invoice_old'] == 1) & (group['instance_id'] == group['bi_instance']),
            'user_access_token'
        ]
    )
    done_cnt = _distinct_count(
        group.loc[
            (group['instance_id'] == group['bi_instance']) & (group['done_just'] == 1),
            'user_access_token'
        ]
    )

    return pd.Series(
        {
            'Open': open_cnt,
            'CR_OPEN_INTERACT': (interact_cnt / open_cnt * 100) if open_cnt else np.nan,
            'CR_OPEN_CREATE': (create_cnt / open_cnt * 100) if open_cnt else np.nan,
            'CR_CREATE_DONE': (done_cnt / create_cnt * 100) if create_cnt else np.nan,
            'CR_OPEN_DONE': (done_cnt / open_cnt * 100) if open_cnt else np.nan,
        }
    )


font_body = getattr(XS, 'FONT_BODY', getattr(XS, 'FONT_SANS', "'Roboto', sans-serif"))
font_title = getattr(XS, 'FONT_TITLE', font_body)
color_s7 = getattr(XS, 'S7', '#31CAE8')
color_s10 = getattr(XS, 'S10', '#B2F2FF')
panel_bg = '#FFFFFF'
year_colors = [getattr(XS, 'S5', XS.PALETTE[0]), getattr(XS, 'S7', XS.PALETTE[1])]

all_panels_html = []
for pid_value, method_label in PAYMENT_METHODS:
    df_method = df_main_my_games_yoy_all[df_main_my_games_yoy_all['pid'] == pid_value].copy()

    method_metrics_df = (
        df_method
        .groupby('year', as_index=False)
        .apply(_calc_yoy_metrics, include_groups=False)
        .reset_index(drop=True)
        .sort_values('year')
    )

    if method_metrics_df.empty:
        panel_html = f"""
        <div class='method-card'>
          <div class='method-title'>{escape(method_label)}</div>
          <div class='method-sub'>No data available</div>
        </div>
        """
        all_panels_html.append(panel_html)
        continue

    years_sorted = sorted(method_metrics_df['year'].dropna().unique().tolist())

    # Compact per-method SVG (fit inside one card)
    svg_width = 420
    left_pad = 150
    right_pad = 36
    top_pad = 34
    row_gap = 56
    bar_h = 12
    group_gap = 6
    inner_w = svg_width - left_pad - right_pad

    max_val = float(np.nanmax(method_metrics_df[METRICS_YOY_ORDER].to_numpy())) if len(method_metrics_df) else 1.0
    if max_val <= 0:
        max_val = 1.0

    def _xscale(v):
        return (float(v) / max_val) * inner_w if pd.notna(v) else 0.0

    rows_svg = []
    for row_idx, metric in enumerate(METRICS_YOY_ORDER):
        y_base = top_pad + row_idx * row_gap
        metric_label = METRICS_YOY_LABELS.get(metric, metric)
        rows_svg.append(
            f"<text x='{left_pad - 10}' y='{y_base + bar_h}' text-anchor='end' class='metric-label'>{escape(metric_label)}</text>"
        )
        rows_svg.append(
            f"<line x1='{left_pad}' y1='{y_base + bar_h + 12}' x2='{left_pad + inner_w}' y2='{y_base + bar_h + 12}' class='grid-line' />"
        )

        for y_idx, year in enumerate(years_sorted):
            val = float(method_metrics_df.loc[method_metrics_df['year'] == year, metric].iloc[0])
            y = y_base + y_idx * (bar_h + group_gap)
            w = _xscale(val)
            color = year_colors[y_idx % len(year_colors)]

            rows_svg.append(
                f"<rect x='{left_pad}' y='{y}' width='{w:.2f}' height='{bar_h}' rx='6' ry='6' fill='{color}' />"
            )
            rows_svg.append(
                f"<text x='{left_pad + w + 6:.2f}' y='{y + bar_h - 2}' class='val-label'>{val:.1f}%</text>"
            )

    axis_ticks = []
    for t in np.linspace(0, max_val, 5):
        x = left_pad + _xscale(t)
        axis_ticks.append(f"<line x1='{x:.2f}' y1='18' x2='{x:.2f}' y2='{top_pad + len(METRICS_YOY_ORDER)*row_gap - 8}' class='tick-line' />")
        axis_ticks.append(f"<text x='{x:.2f}' y='{top_pad + len(METRICS_YOY_ORDER)*row_gap + 10}' text-anchor='middle' class='tick-label'>{t:.0f}%</text>")

    svg_height = top_pad + len(METRICS_YOY_ORDER) * row_gap + 24

    legend_html = ''.join(
        [
            f"<div class='legend-item'><span class='sw' style='background:{year_colors[idx % len(year_colors)]};'></span>{int(year)}</div>"
            for idx, year in enumerate(years_sorted)
        ]
    )

    open_cards = ''.join(
        [
            (
                "<div class='kpi-chip'>"
                f"<div class='kpi-chip-year'>{int(r['year'])}</div>"
                f"<div class='kpi-chip-val'>{int(r['Open']):,}</div>"
                "</div>"
            )
            for _, r in method_metrics_df[['year', 'Open']].iterrows()
        ]
    )

    panel_html = f"""
    <div class='method-card'>
      <div class='method-title'>{escape(method_label)}</div>
      <div class='method-kpi-row'>{open_cards}</div>
      <div class='method-panel'>
        <div class='legend'>{legend_html}</div>
        <svg width='100%' viewBox='0 0 {svg_width} {svg_height}' preserveAspectRatio='xMinYMin meet' role='img' aria-label='YoY chart for {escape(method_label)}'>
          {''.join(axis_ticks)}
          {''.join(rows_svg)}
        </svg>
      </div>
    </div>
    """
    all_panels_html.append(panel_html)

fig_html = f"""
<!DOCTYPE html>
<html>
<head>
<meta charset='utf-8'>
<link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
<style>
  body {{ background:#FFFFFF; margin:0; padding:16px; font-family:{font_body}; color:{XS.TEXT_PRIMARY}; }}
  .grid-4 {{ display:grid; grid-template-columns:repeat(4, minmax(0, 1fr)); gap:14px; align-items:start; }}
  .method-card {{ background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:10px; }}
  .method-title {{ font-family:{font_title}; font-size:22px; font-weight:700; line-height:1.15; margin:0 0 8px; }}
  .method-kpi-row {{ display:grid; grid-template-columns:repeat(2, minmax(0, 1fr)); gap:8px; margin-bottom:10px; }}
  .kpi-chip {{ border:1px solid #D3D3D3; border-radius:10px; overflow:hidden; background:#FFFFFF; }}
  .kpi-chip-year {{ background:{color_s10}; text-align:center; font-size:12px; font-weight:700; padding:4px 6px; }}
  .kpi-chip-val {{ text-align:center; color:{color_s7}; font-size:26px; font-weight:700; line-height:1.1; padding:6px 4px 8px; }}
  .method-panel {{ background:{panel_bg}; border:1px solid #D0D7DA; border-radius:12px; padding:8px; overflow:hidden; }}
  .legend {{ display:flex; gap:14px; margin:0 0 8px; flex-wrap:wrap; }}
  .legend-item {{ font-size:11px; color:{XS.TEXT_SECONDARY}; display:flex; align-items:center; gap:6px; }}
  .sw {{ width:14px; height:8px; border-radius:4px; display:inline-block; }}
  .metric-label {{ font-size:11px; fill:{XS.TEXT_PRIMARY}; font-weight:700; font-family:{font_body}; }}
  .val-label {{ font-size:10px; fill:{XS.TEXT_PRIMARY}; font-weight:700; font-family:{font_body}; }}
  .grid-line {{ stroke:#C0C0C0; stroke-width:1; }}
  .tick-line {{ stroke:#E6E6E6; stroke-width:1; }}
  .tick-label {{ font-size:10px; fill:{XS.TEXT_SECONDARY}; font-family:{font_body}; }}
</style>
</head>
<body>
  <div class='grid-4'>
    {''.join(all_panels_html)}
  </div>
</body>
</html>
"""

display(HTML(fig_html))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset='utf-8'>
# <link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
# <style>
#   body { background:#FFFFFF; margin:0; padding:16px; font-family:'Roboto', sans-serif; color:#011627; }
#   .grid-4 { display:grid; grid-template-columns:repeat(4, minmax(0, 1fr)); gap:14px; align-items:start; }
#   .method-card { background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:10px; }
#   .method-title { font-family:'Open Sans', sans-serif; font-size:22px; font-weight:700; line-height:1.15; margin:0 0 8px; }
#   .method-kpi-row { display:grid; grid-template-columns:repeat(2, minmax(0, 1fr)); gap:8px; margin-bottom:10px; }
#   .kpi-chip { border:1px solid #D3D3D3; border-radius:10px; overflow:hidden; background:#FFFFFF; }
#   .kpi-chip-year { background:#B2F2FF; text-align:center; font-size:12px; font-weight:700; padding:4px 6px; }
#   .kpi-chip-val { text-align:center; color:#31CAE8; font-size:26px; font-weight:700; line-height:1.1; padding:6px 4px 8px; }
#   .method-panel { background:#FFFFFF; border:1px solid #D0D7DA; border-radius:12px; padding:8px; overflow:hidden; }
#   .legend { display:flex; gap:14px; margin:0 0 8px; flex-wrap:wrap; }
#   .legend-item { font-size:11px; color:#595959; display:flex; align-items:center; gap:6px; }
#   .sw { width:14px; height:8px; border-radius:4px; display:inline-block; }
#   .metric-label { font-size:11px; fill:#011627; font-weight:700; font-family:'Roboto', sans-serif; }
#   .val-label { font-size:10px; fill:#011627; font-weight:700; font-family:'Roboto', sans-serif; }
#   .grid-line { stroke:#C0C0C0; stroke-width:1; }
#   .tick-line { stroke:#E6E6E6; stroke-width:1; }
#   .tick-label { font-size:10px; fill:#595959; font-family:'Roboto', sans-serif; }
# </style>
# </head>
# <body>
#   <div class='grid-4'>
#
#     <div class='method-card'>
#       <div class='method-title'>Bank card</div>
#       <div class='method-kpi-row'><div class='kpi-chip'><div class='kpi-chip-year'>2025</div><div class='kpi-chip-val'>80,116</div></div><div class='kpi-chip'><div class='kpi-chip-year'>2026</div><div class='kpi-chip-val'>310,727</div></div></div>
#       <div class='method-panel'>
#         <div class='legend'><div class='legend-item'><span class='sw' style='background:#1B8398;'></span>2025</div><div class='legend-item'><span class='sw' style='background:#31CAE8;'></span>2026</div></div>
#         <svg width='100%' viewBox='0 0 420 282' preserveAspectRatio='xMinYMin meet' role='img' aria-label='YoY chart for Bank card'>
#           <line x1='150.00' y1='18' x2='150.00' y2='250' class='tick-line' /><text x='150.00' y='268' text-anchor='middle' class='tick-label'>0%</text><line x1='208.50' y1='18' x2='208.50' y2='250' class='tick-line' /><text x='208.50' y='268' text-anchor='middle' class='tick-label'>22%</text><line x1='267.00' y1='18' x2='267.00' y2='250' class='tick-line' /><text x='267.00' y='268' text-anchor='middle' class='tick-label'>44%</text><line x1='325.50' y1='18' x2='325.50' y2='250' class='tick-line' /><text x='325.50' y='268' text-anchor='middle' class='tick-label'>66%</text><line x1='384.00' y1='18' x2='384.00' y2='250' class='tick-line' /><text x='384.00' y='268' text-anchor='middle' class='tick-label'>88%</text>
#           <text x='140' y='46' text-anchor='end' class='metric-label'>CR Open-Interact</text><line x1='150' y1='58' x2='384' y2='58' class='grid-line' /><rect x='150' y='34' width='209.15' height='12' rx='6' ry='6' fill='#1B8398' /><text x='365.15' y='44' class='val-label'>78.4%</text><rect x='150' y='52' width='190.46' height='12' rx='6' ry='6' fill='#31CAE8' /><text x='346.46' y='62' class='val-label'>71.4%</text><text x='140' y='102' text-anchor='end' class='metric-label'>CR Open-Create</text><line x1='150' y1='114' x2='384' y2='114' class='grid-line' /><rect x='150' y='90' width='73.95' height='12' rx='6' ry='6' fill='#1B8398' /><text x='229.95' y='100' class='val-label'>27.7%</text><rect x='150' y='108' width='69.50' height='12' rx='6' ry='6' fill='#31CAE8' /><text x='225.50' y='118' class='val-label'>26.0%</text><text x='140' y='158' text-anchor='end' class='metric-label'>CR Create-Done</text><line x1='150' y1='170' x2='384' y2='170' class='grid-line' /><rect x='150' y='146' width='221.83' height='12' rx='6' ry='6' fill='#1B8398' /><text x='377.83' y='156' class='val-label'>83.1%</text><rect x='150' y='164' width='234.00' height='12' rx='6' ry='6' fill='#31CAE8' /><text x='390.00' y='174' class='val-label'>87.7%</text><text x='140' y='214' text-anchor='end' class='metric-label'>CR Open-Done</text><line x1='150' y1='226' x2='384' y2='226' class='grid-line' /><rect x='150' y='202' width='61.48' height='12' rx='6' ry='6' fill='#1B8398' /><text x='217.48' y='212' class='val-label'>23.0%</text><rect x='150' y='220' width='60.95' height='12' rx='6' ry='6' fill='#31CAE8' /><text x='216.95' y='230' class='val-label'>22.8%</text>
#         </svg>
#       </div>
#     </div>
#
#     <div class='method-card'>
#       <div class='method-title'>Apple Pay</div>
#       <div class='method-kpi-row'><div class='kpi-chip'><div class='kpi-chip-year'>2025</div><div class='kpi-chip-val'>24,724</div></div><div class='kpi-chip'><div class='kpi-chip-year'>2026</div><div class='kpi-chip-val'>85,690</div></div></div>
#       <div class='method-panel'>
#         <div class='legend'><div class='legend-item'><span class='sw' style='background:#1B8398;'></span>2025</div><div class='legend-item'><span class='sw' style='background:#31CAE8;'></span>2026</div></div>
#         <svg width='100%' viewBox='0 0 420 282' preserveAspectRatio='xMinYMin meet' role='img' aria-label='YoY chart for Apple Pay'>
#           <line x1='150.00' y1='18' x2='150.00' y2='250' class='tick-line' /><text x='150.00' y='268' text-anchor='middle' class='tick-label'>0%</text><line x1='208.50' y1='18' x2='208.50' y2='250' class='tick-line' /><text x='208.50' y='268' text-anchor='middle' class='tick-label'>25%</text><line x1='267.00' y1='18' x2='267.00' y2='250' class='tick-line' /><text x='267.00' y='268' text-anchor='middle' class='tick-label'>50%</text><line x1='325.50' y1='18' x2='325.50' y2='250' class='tick-line' /><text x='325.50' y='268' text-anchor='middle' class='tick-label'>75%</text><line x1='384.00' y1='18' x2='384.00' y2='250' class='tick-line' /><text x='384.00' y='268' text-anchor='middle' class='tick-label'>100%</text>
#           <text x='140' y='46' text-anchor='end' class='metric-label'>CR Open-Interact</text><line x1='150' y1='58' x2='384' y2='58' class='grid-line' /><rect x='150' y='34' width='234.00' height='12' rx='6' ry='6' fill='#1B8398' /><text x='390.00' y='44' class='val-label'>99.8%</text><rect x='150' y='52' width='233.79' height='12' rx='6' ry='6' fill='#31CAE8' /><text x='389.79' y='62' class='val-label'>99.7%</text><text x='140' y='102' text-anchor='end' class='metric-label'>CR Open-Create</text><line x1='150' y1='114' x2='384' y2='114' class='grid-line' /><rect x='150' y='90' width='201.17' height='12' rx='6' ry='6' fill='#1B8398' /><text x='357.17' y='100' class='val-label'>85.8%</text><rect x='150' y='108' width='205.32' height='12' rx='6' ry='6' fill='#31CAE8' /><text x='361.32' y='118' class='val-label'>87.6%</text><text x='140' y='158' text-anchor='end' class='metric-label'>CR Create-Done</text><line x1='150' y1='170' x2='384' y2='170' class='grid-line' /><rect x='150' y='146' width='213.66' height='12' rx='6' ry='6' fill='#1B8398' /><text x='369.66' y='156' class='val-label'>91.1%</text><rect x='150' y='164' width='210.66' height='12' rx='6' ry='6' fill='#31CAE8' /><text x='366.66' y='174' class='val-label'>89.9%</text><text x='140' y='214' text-anchor='end' class='metric-label'>CR Open-Done</text><line x1='150' y1='226' x2='384' y2='226' class='grid-line' /><rect x='150' y='202' width='183.36' height='12' rx='6' ry='6' fill='#1B8398' /><text x='339.36' y='212' class='val-label'>78.2%</text><rect x='150' y='220' width='184.52' height='12' rx='6' ry='6' fill='

# %%
# Traffic distribution by project (Game)

from html import escape
from IPython.display import HTML, display

traffic_by_game_df = (
    df_main_my_games
    .dropna(subset=['game_name', 'user_access_token'])
    .groupby('game_name', as_index=False)
    .agg(unique_access_tokens=('user_access_token', 'nunique'))
    .sort_values('unique_access_tokens', ascending=False)
)

# Keep only top-10 projects for chart
traffic_chart_df = traffic_by_game_df.head(10).copy()

font_body = getattr(XS, 'FONT_BODY', getattr(XS, 'FONT_SANS', "'Roboto', sans-serif"))
font_title = getattr(XS, 'FONT_TITLE', font_body)
bar_color = getattr(XS, 'S7', XS.PALETTE[0])
track_color = getattr(XS, 'S12', '#EBFCFF')
grid_major = getattr(XS, 'GRID_MAJOR', '#C0C0C0')
text_primary = XS.TEXT_PRIMARY
text_secondary = XS.TEXT_SECONDARY

svg_width = 980
left_pad = 280
right_pad = 60
top_pad = 40
row_gap = 36
bar_h = 20
inner_w = svg_width - left_pad - right_pad

max_val = float(traffic_chart_df['unique_access_tokens'].max()) if len(traffic_chart_df) else 1.0
if max_val <= 0:
    max_val = 1.0


def _xscale(v):
    return float(v) / max_val * inner_w

rows_svg = []
for idx, row in traffic_chart_df.reset_index(drop=True).iterrows():
    y = top_pad + idx * row_gap
    game = str(row['game_name'])
    val = int(row['unique_access_tokens'])
    w = _xscale(val)

    rows_svg.append(
        f"<text x='{left_pad - 14}' y='{y + bar_h - 4}' text-anchor='end' class='tdp-y-label'>{escape(game)}</text>"
    )
    rows_svg.append(
        f"<rect x='{left_pad}' y='{y}' width='{inner_w}' height='{bar_h}' rx='9' ry='9' fill='{track_color}' />"
    )
    rows_svg.append(
        f"<rect x='{left_pad}' y='{y}' width='{w:.2f}' height='{bar_h}' rx='9' ry='9' fill='{bar_color}' />"
    )
    rows_svg.append(
        f"<text x='{left_pad + w + 8:.2f}' y='{y + bar_h - 4}' class='tdp-v-label'>{val:,}</text>"
    )

axis_ticks = []
for t in np.linspace(0, max_val, 6):
    x = left_pad + _xscale(t)
    axis_ticks.append(f"<line x1='{x:.2f}' y1='16' x2='{x:.2f}' y2='{top_pad + len(traffic_chart_df)*row_gap - 8}' class='tdp-tick-line' />")
    axis_ticks.append(f"<text x='{x:.2f}' y='{top_pad + len(traffic_chart_df)*row_gap + 16}' text-anchor='middle' class='tdp-tick-label'>{int(t):,}</text>")

svg_height = top_pad + len(traffic_chart_df) * row_gap + 28

total_tokens = int(traffic_chart_df['unique_access_tokens'].sum()) if len(traffic_chart_df) else 0
project_count_all = int(traffic_by_game_df['game_name'].nunique()) if len(traffic_by_game_df) else 0
all_projects_total_tokens = int(traffic_by_game_df['unique_access_tokens'].sum()) if len(traffic_by_game_df) else 0
top10_share_pct = (total_tokens / all_projects_total_tokens * 100) if all_projects_total_tokens else 0.0

fig_html = f"""
<!DOCTYPE html>
<html>
<head>
<meta charset='utf-8'>
<link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
<style>
  body {{ background:#FFFFFF; margin:0; padding:18px; font-family:{font_body}; color:{text_primary}; }}
  .tdp-wrap {{ background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:14px; }}
  .tdp-title {{ font-family:{font_title}; font-size:34px; font-weight:700; line-height:1.1; margin:0 0 4px; }}
  .tdp-subtitle {{ font-size:14px; color:{text_secondary}; margin:0 0 10px; }}
  .tdp-kpi-row {{ display:grid; grid-template-columns:repeat(3,minmax(0,1fr)); gap:10px; margin-bottom:12px; }}
  .tdp-kpi {{ border:1px solid #D3D3D3; border-radius:10px; overflow:hidden; background:#FFFFFF; }}
  .tdp-kpi-h {{ background:{track_color}; text-align:center; font-size:13px; font-weight:700; padding:5px 6px; }}
  .tdp-kpi-v {{ text-align:center; color:{bar_color}; font-size:34px; font-weight:700; padding:6px 6px 8px; line-height:1; }}
  .tdp-panel {{ background:#FFFFFF; border:1px solid #D0D7DA; border-radius:12px; padding:8px; overflow:hidden; }}
  .tdp-y-label {{ font-size:12px; fill:{text_primary}; font-weight:500; font-family:{font_body}; }}
  .tdp-v-label {{ font-size:12px; fill:{text_primary}; font-weight:700; font-family:{font_body}; }}
  .tdp-tick-line {{ stroke:{grid_major}; stroke-width:1; }}
  .tdp-tick-label {{ font-size:11px; fill:{text_secondary}; font-family:{font_body}; }}
</style>
</head>
<body>
  <div class='tdp-wrap'>
    <div class='tdp-title'>Traffic Distribution by Project</div>
    <div class='tdp-subtitle'>Metric: unique user access tokens by Game</div>
    <div class='tdp-kpi-row'>
      <div class='tdp-kpi'><div class='tdp-kpi-h'>All projects in sample (Game)</div><div class='tdp-kpi-v'>{project_count_all:,}</div></div>
      <div class='tdp-kpi'><div class='tdp-kpi-h'>Total unique access tokens</div><div class='tdp-kpi-v'>{total_tokens:,}</div></div>
      <div class='tdp-kpi'><div class='tdp-kpi-h'>Top-10 traffic share</div><div class='tdp-kpi-v'>{top10_share_pct:.2f}%</div></div>
    </div>
    <div class='tdp-panel'>
      <svg width='100%' viewBox='0 0 {svg_width} {svg_height}' preserveAspectRatio='xMinYMin meet' role='img' aria-label='Traffic distribution by project'>
        {''.join(axis_ticks)}
        {''.join(rows_svg)}
      </svg>
    </div>
  </div>
</body>
</html>
"""

display(HTML(fig_html))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset='utf-8'>
# <link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
# <style>
#   body { background:#FFFFFF; margin:0; padding:18px; font-family:'Roboto', sans-serif; color:#011627; }
#   .tdp-wrap { background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:14px; }
#   .tdp-title { font-family:'Open Sans', sans-serif; font-size:34px; font-weight:700; line-height:1.1; margin:0 0 4px; }
#   .tdp-subtitle { font-size:14px; color:#595959; margin:0 0 10px; }
#   .tdp-kpi-row { display:grid; grid-template-columns:repeat(3,minmax(0,1fr)); gap:10px; margin-bottom:12px; }
#   .tdp-kpi { border:1px solid #D3D3D3; border-radius:10px; overflow:hidden; background:#FFFFFF; }
#   .tdp-kpi-h { background:#EBFCFF; text-align:center; font-size:13px; font-weight:700; padding:5px 6px; }
#   .tdp-kpi-v { text-align:center; color:#31CAE8; font-size:34px; font-weight:700; padding:6px 6px 8px; line-height:1; }
#   .tdp-panel { background:#FFFFFF; border:1px solid #D0D7DA; border-radius:12px; padding:8px; overflow:hidden; }
#   .tdp-y-label { font-size:12px; fill:#011627; font-weight:500; font-family:'Roboto', sans-serif; }
#   .tdp-v-label { font-size:12px; fill:#011627; font-weight:700; font-family:'Roboto', sans-serif; }
#   .tdp-tick-line { stroke:#C0C0C0; stroke-width:1; }
#   .tdp-tick-label { font-size:11px; fill:#595959; font-family:'Roboto', sans-serif; }
# </style>
# </head>
# <body>
#   <div class='tdp-wrap'>
#     <div class='tdp-title'>Traffic Distribution by Project</div>
#     <div class='tdp-subtitle'>Metric: unique user access tokens by Game</div>
#     <div class='tdp-kpi-row'>
#       <div class='tdp-kpi'><div class='tdp-kpi-h'>All projects in sample (Game)</div><div class='tdp-kpi-v'>66</div></div>
#       <div class='tdp-kpi'><div class='tdp-kpi-h'>Total unique access tokens</div><div class='tdp-kpi-v'>454,245</div></div>
#       <div class='tdp-kpi'><div class='tdp-kpi-h'>Top-10 traffic share</div><div class='tdp-kpi-v'>95.84%</div></div>
#     </div>
#     <div class='tdp-panel'>
#       <svg width='100%' viewBox='0 0 1220 428' preserveAspectRatio='xMinYMin meet' role='img' aria-label='Traffic distribution by project'>
#         <line x1='360.00' y1='16' x2='360.00' y2='392' class='tdp-tick-line' /><text x='360.00' y='416' text-anchor='middle' class='tdp-tick-label'>0</text><line x1='510.00' y1='16' x2='510.00' y2='392' class='tdp-tick-line' /><text x='510.00' y='416' text-anchor='middle' class='tdp-tick-label'>50,736</text><line x1='660.00' y1='16' x2='660.00' y2='392' class='tdp-tick-line' /><text x='660.00' y='416' text-anchor='middle' class='tdp-tick-label'>101,473</text><line x1='810.00' y1='16' x2='810.00' y2='392' class='tdp-tick-line' /><text x='810.00' y='416' text-anchor='middle' class='tdp-tick-label'>152,209</text><line x1='960.00' y1='16' x2='960.00' y2='392' class='tdp-tick-line' /><text x='960.00' y='416' text-anchor='middle' class='tdp-tick-label'>202,946</text><line x1='1110.00' y1='16' x2='1110.00' y2='392' class='tdp-tick-line' /><text x='1110.00' y='416' text-anchor='middle' class='tdp-tick-label'>253,683</text>
#         <text x='346' y='56' text-anchor='end' class='tdp-y-label'>[XSOLLA][WV] War Robots WW</text><rect x='360' y='40' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='40' width='750.00' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='1118.00' y='56' class='tdp-v-label'>253,683</text><text x='346' y='92' text-anchor='end' class='tdp-y-label'>[XSOLLA][WV] Rush Royale WW</text><rect x='360' y='76' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='76' width='212.06' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='580.06' y='92' class='tdp-v-label'>71,728</text><text x='346' y='128' text-anchor='end' class='tdp-y-label'>[XSOLLA][WV] Grand Hotel Mania WW</text><rect x='360' y='112' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='112' width='88.00' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='456.00' y='128' class='tdp-v-label'>29,767</text><text x='346' y='164' text-anchor='end' class='tdp-y-label'>[XSOLLA][WV] Tacticool WW</text><rect x='360' y='148' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='148' width='65.09' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='433.09' y='164' class='tdp-v-label'>22,016</text><text x='346' y='200' text-anchor='end' class='tdp-y-label'>[XSOLLA][WV] Hustle Castle WW</text><rect x='360' y='184' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='184' width='57.09' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='425.09' y='200' class='tdp-v-label'>19,312</text><text x='346' y='236' text-anchor='end' class='tdp-y-label'>[XSOLLA][TP] War Robots WW</text><rect x='360' y='220' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='220' width='46.41' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='414.41' y='236' class='tdp-v-label'>15,699</text><text x='346' y='272' text-anchor='end' class='tdp-y-label'>[XSOLLA][TP] Grand Hotel Mania WW</text><rect x='360' y='256' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='256' width='37.73' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='405.73' y='272' class='tdp-v-label'>12,763</text><text x='346' y='308' text-anchor='end' class='tdp-y-label'>[XSOLLA][WV] LTS WW</text><rect x='360' y='292' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='292' width='35.64' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='403.64' y='308' class='tdp-v-label'>12,054</text><text x='346' y='344' text-anchor='end' class='tdp-y-label'>[XSOLLA][TP] Rush Royale WW</text><rect x='360' y='328' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='328' width='33.03' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='401.03' y='344' class='tdp-v-label'>11,173</text><text x='346' y='380' text-anchor='end' class='tdp-y-label'>[XSOLLA][WS] Global City WW</text><rect x='360' y='364' width='750' height='20' rx='9' ry='9' fill='#EBFCFF' /><rect x='360' y='364' width='17.89' height='20' rx='9' ry='9' fill='#31CAE8' /><text x='385.89' y='380' class='tdp-v-label'>6,050</text>
#       </svg>
#     </div>
#   </div>
# </body>
# </html>

# %%
# The language of the Pay Station opening

from html import escape
from math import cos, sin, pi
from IPython.display import HTML, display

locale_df = (
    df_main_my_games
    .dropna(subset=['user_access_token', 'user_locale'])
    .groupby('user_locale', as_index=False)
    .agg(unique_tokens=('user_access_token', 'nunique'))
    .sort_values('unique_tokens', ascending=False)
)

locale_df['share_pct'] = locale_df['unique_tokens'] / locale_df['unique_tokens'].sum() * 100 if len(locale_df) else 0.0

# Show top locales like in template
locale_view_df = locale_df.head(6).copy()

if len(locale_df):
    total_tokens = int(locale_df['unique_tokens'].sum())
    top_locale = str(locale_df.iloc[0]['user_locale'])
    top_locale_share = float(locale_df.iloc[0]['share_pct'])
else:
    total_tokens = 0
    top_locale = '-'
    top_locale_share = 0.0

font_body = getattr(XS, 'FONT_BODY', getattr(XS, 'FONT_SANS', "'Roboto', sans-serif"))
font_title = getattr(XS, 'FONT_TITLE', font_body)

palette = [
    getattr(XS, 'S5', XS.PALETTE[0]),
    getattr(XS, 'S6', XS.PALETTE[1]),
    getattr(XS, 'S7', XS.PALETTE[2] if len(XS.PALETTE) > 2 else XS.PALETTE[0]),
    getattr(XS, 'S8', XS.PALETTE[0]),
    getattr(XS, 'S9', XS.PALETTE[1]),
    getattr(XS, 'S10', '#B2F2FF'),
]


def donut_segment_path(cx, cy, r_outer, r_inner, start_angle, end_angle):
    large_arc = 1 if (end_angle - start_angle) > pi else 0
    x1o = cx + r_outer * cos(start_angle)
    y1o = cy + r_outer * sin(start_angle)
    x2o = cx + r_outer * cos(end_angle)
    y2o = cy + r_outer * sin(end_angle)
    x2i = cx + r_inner * cos(end_angle)
    y2i = cy + r_inner * sin(end_angle)
    x1i = cx + r_inner * cos(start_angle)
    y1i = cy + r_inner * sin(start_angle)

    return (
        f"M {x1o:.3f} {y1o:.3f} "
        f"A {r_outer:.3f} {r_outer:.3f} 0 {large_arc} 1 {x2o:.3f} {y2o:.3f} "
        f"L {x2i:.3f} {y2i:.3f} "
        f"A {r_inner:.3f} {r_inner:.3f} 0 {large_arc} 0 {x1i:.3f} {y1i:.3f} Z"
    )


donut_paths = []
start = -pi / 2
cx, cy = 200, 205
r_outer, r_inner = 145, 96

for idx, row in locale_view_df.reset_index(drop=True).iterrows():
    share = float(row['share_pct'])
    angle = (share / 100.0) * 2 * pi
    end = start + angle
    color = palette[idx % len(palette)]
    path = donut_segment_path(cx, cy, r_outer, r_inner, start, end)
    donut_paths.append(f"<path d='{path}' fill='{color}'></path>")
    start = end

legend_rows = []
for idx, row in locale_view_df.reset_index(drop=True).iterrows():
    color = palette[idx % len(palette)]
    legend_rows.append(
        "<div class='legend-row'>"
        f"<div class='legend-left'><span class='dot' style='background:{color}'></span><span class='locale'>{escape(str(row['user_locale']))}</span></div>"
        f"<div class='legend-right'><span class='count'>{int(row['unique_tokens']):,}</span><span class='share'>{row['share_pct']:.2f}% share</span></div>"
        "</div>"
    )

fig_html = f"""
<!DOCTYPE html>
<html>
<head>
<meta charset='utf-8'>
<link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
<style>
  body {{ background:#FFFFFF; margin:0; padding:18px; font-family:{font_body}; color:{XS.TEXT_PRIMARY}; }}
  .wrap {{ background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:12px; max-width: 760px; }}
  .title {{ font-family:{font_title}; font-size:34px; font-weight:700; line-height:1.1; margin:0 0 2px; }}
  .subtitle {{ font-size:13px; color:{XS.TEXT_SECONDARY}; margin:0 0 10px; }}
  .kpi-row {{ display:grid; grid-template-columns:repeat(2,minmax(0,1fr)); gap:10px; margin-bottom:12px; }}
  .kpi {{ border:1px solid #D3D3D3; border-radius:14px; overflow:hidden; background:#FFFFFF; }}
  .kpi-h {{ background:{getattr(XS, 'S10', '#B2F2FF')}; text-align:center; font-size:13px; font-weight:700; padding:6px 8px; }}
  .kpi-v {{ text-align:center; color:{getattr(XS, 'S5', '#1B8398')}; font-size:42px; font-weight:700; line-height:1.0; padding:8px 8px 4px; }}
  .kpi-n {{ text-align:center; font-size:13px; color:{XS.TEXT_SECONDARY}; padding:0 8px 10px; }}
  .panel {{ background:#FFFFFF; border:1px solid #D0D7DA; border-radius:12px; padding:14px; }}
  .content {{ display:grid; grid-template-columns:320px 1fr; gap:16px; align-items:center; }}
  .donut-wrap {{ display:flex; align-items:center; justify-content:center; }}
  .center-text {{ font-family:{font_title}; font-size:44px; font-weight:700; fill:{getattr(XS, 'S5', '#1B8398')}; text-anchor:middle; }}
  .center-sub {{ font-size:16px; fill:{XS.TEXT_SECONDARY}; text-anchor:middle; }}
  .legend-row {{ display:flex; justify-content:space-between; align-items:center; padding:8px 0; border-bottom:1px solid #EEF2F4; }}
  .legend-row:last-child {{ border-bottom:none; }}
  .legend-left {{ display:flex; align-items:center; gap:10px; }}
  .dot {{ width:14px; height:14px; border-radius:4px; display:inline-block; }}
  .locale {{ font-size:22px; font-weight:700; color:{XS.TEXT_PRIMARY}; line-height:1; }}
  .legend-right {{ display:flex; align-items:baseline; gap:12px; }}
  .count {{ font-size:24px; font-weight:700; color:{getattr(XS, 'S5', '#1B8398')}; }}
  .share {{ font-size:20px; color:{XS.TEXT_SECONDARY}; }}
</style>
</head>
<body>
  <div class='wrap'>
    <div class='title'>The language of the Pay Station opening</div>
    <div class='subtitle'></div>

    <div class='kpi-row'>
      <div class='kpi'>
        <div class='kpi-h'>Total tokens</div>
        <div class='kpi-v'>{total_tokens:,}</div>
        <div class='kpi-n'>Unique user access tokens</div>
      </div>
      <div class='kpi'>
        <div class='kpi-h'>Top language</div>
        <div class='kpi-v'>{escape(top_locale)} - {top_locale_share:.2f}%</div>
        <div class='kpi-n'>Most common opening language</div>
      </div>
    </div>

    <div class='panel'>
      <div class='content'>
        <div class='donut-wrap'>
          <svg width='360' height='360' viewBox='0 0 400 400' role='img' aria-label='Top language share donut'>
            {''.join(donut_paths)}
            <text x='200' y='205' class='center-text'>{top_locale_share:.2f}%</text>
            <text x='200' y='244' class='center-sub'>Top language share</text>
          </svg>
        </div>
        <div>
          {''.join(legend_rows)}
        </div>
      </div>
    </div>
  </div>
</body>
</html>
"""

display(HTML(fig_html))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset='utf-8'>
# <link rel='stylesheet' href='https://fonts.googleapis.com/css2?family=Open+Sans:wght@400;700&family=Roboto:wght@400;500;700&display=swap'>
# <style>
#   body { background:#FFFFFF; margin:0; padding:18px; font-family:'Roboto', sans-serif; color:#011627; }
#   .wrap { background:#FFFFFF; border:2px solid #D0D7DA; border-radius:14px; padding:12px; max-width: 760px; }
#   .title { font-family:'Open Sans', sans-serif; font-size:34px; font-weight:700; line-height:1.1; margin:0 0 2px; }
#   .subtitle { font-size:13px; color:#595959; margin:0 0 10px; }
#   .kpi-row { display:grid; grid-template-columns:repeat(2,minmax(0,1fr)); gap:10px; margin-bottom:12px; }
#   .kpi { border:1px solid #D3D3D3; border-radius:14px; overflow:hidden; background:#FFFFFF; }
#   .kpi-h { background:#B2F2FF; text-align:center; font-size:13px; font-weight:700; padding:6px 8px; }
#   .kpi-v { text-align:center; color:#1B8398; font-size:42px; font-weight:700; line-height:1.0; padding:8px 8px 4px; }
#   .kpi-n { text-align:center; font-size:13px; color:#595959; padding:0 8px 10px; }
#   .panel { background:#FFFFFF; border:1px solid #D0D7DA; border-radius:12px; padding:14px; }
#   .content { display:grid; grid-template-columns:320px 1fr; gap:16px; align-items:center; }
#   .donut-wrap { display:flex; align-items:center; justify-content:center; }
#   .center-text { font-family:'Open Sans', sans-serif; font-size:44px; font-weight:700; fill:#1B8398; text-anchor:middle; }
#   .center-sub { font-size:16px; fill:#595959; text-anchor:middle; }
#   .legend-row { display:flex; justify-content:space-between; align-items:center; padding:8px 0; border-bottom:1px solid #EEF2F4; }
#   .legend-row:last-child { border-bottom:none; }
#   .legend-left { display:flex; align-items:center; gap:10px; }
#   .dot { width:14px; height:14px; border-radius:4px; display:inline-block; }
#   .locale { font-size:22px; font-weight:700; color:#011627; line-height:1; }
#   .legend-right { display:flex; align-items:baseline; gap:12px; }
#   .count { font-size:24px; font-weight:700; color:#1B8398; }
#   .share { font-size:20px; color:#595959; }
# </style>
# </head>
# <body>
#   <div class='wrap'>
#     <div class='title'>The language of the Pay Station opening</div>
#     <div class='subtitle'></div>
#
#     <div class='kpi-row'>
#       <div class='kpi'>
#         <div class='kpi-h'>Total tokens</div>
#         <div class='kpi-v'>473,993</div>
#         <div class='kpi-n'>Unique user access tokens</div>
#       </div>
#       <div class='kpi'>
#         <div class='kpi-h'>Top language</div>
#         <div class='kpi-v'>en - 95.08%</div>
#         <div class='kpi-n'>Most common opening language</div>
#       </div>
#     </div>
#
#     <div class='panel'>
#       <div class='content'>
#         <div class='donut-wrap'>
#           <svg width='360' height='360' viewBox='0 0 400 400' role='img' aria-label='Top language share donut'>
#             <path d='M 200.000 60.000 A 145.000 145.000 0 1 1 155.847 66.886 L 170.768 113.559 A 96.000 96.000 0 1 0 200.000 109.000 Z' fill='#1B8398'></path><path d='M 155.847 66.886 A 145.000 145.000 0 0 1 187.068 60.578 L 191.438 109.383 A 96.000 96.000 0 0 0 170.768 113.559 Z' fill='#22A8C3'></path><path d='M 187.068 60.578 A 145.000 145.000 0 0 1 195.390 60.073 L 196.948 109.049 A 96.000 96.000 0 0 0 191.438 109.383 Z' fill='#31CAE8'></path><path d='M 195.390 60.073 A 145.000 145.000 0 0 1 196.610 60.040 L 197.755 109.026 A 96.000 96.000 0 0 0 196.948 109.049 Z' fill='#55DCF6'></path><path d='M 196.610 60.040 A 145.000 145.000 0 0 1 197.134 60.028 L 198.103 109.019 A 96.000 96.000 0 0 0 197.755 109.026 Z' fill='#80EAFF'></path><path d='M 197.134 60.028 A 145.000 145.000 0 0 1 197.634 60.019 L 198.434 109.013 A 96.000 96.000 0 0 0 198.103 109.019 Z' fill='#B2F2FF'></path>
#             <text x='200' y='205' class='center-text'>95.08%</text>
#             <text x='200' y='244' class='center-sub'>Top language share</text>
#           </svg>
#         </div>
#         <div>
#           <div class='legend-row'><div class='legend-left'><span class='dot' style='background:#1B8398'></span><span class='locale'>en</span></div><div class='legend-right'><span class='count'>450,651</span><span class='share'>95.08% share</span></div></div><div class='legend-row'><div class='legend-left'><span class='dot' style='background:#22A8C3'></span><span class='locale'>es</span></div><div class='legend-right'><span class='count'>16,605</span><span class='share'>3.50% share</span></div></div><div class='legend-row'><div class='legend-left'><span class='dot' style='background:#31CAE8'></span><span class='locale'>ru</span></div><div class='legend-right'><span class='count'>4,338</span><span class='share'>0.92% share</span></div></div><div class='legend-row'><div class='legend-left'><span class='dot' style='background:#55DCF6'></span><span class='locale'>vi</span></div><div class='legend-right'><span class='count'>635</span><span class='share'>0.13% share</span></div></div><div class='legend-row'><div class='legend-left'><span class='dot' style='background:#80EAFF'></span><span class='locale'>de</span></div><div class='legend-right'><span class='count'>273</span><span class='share'>0.06% share</span></div></div><div class='legend-row'><div class='legend-left'><span class='dot' style='background:#B2F2FF'></span><span class='locale'>pt</span></div><div class='legend-right'><span class='count'>260</span><span class='share'>0.05% share</span></div></div>
#         </div>
#       </div>
#     </div>
#   </div>
# </body>
# </html>
